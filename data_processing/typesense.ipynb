# %%
# pip install typesense
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import typesense
import pandas as pd
import json
import requests
import time

# %%
client = typesense.Client({
  'nodes': [{
    'host': 'f0dmgj8v7bzpyr9tp-1.a1.typesense.net',
    'port': '443',
    'protocol': 'https'
  }],
  'api_key': 'EWlZebXfKJjAk3EtQMY2Xye97KyOB559',
  'connection_timeout_seconds': 10
})

# %%
while not client.operations.is_healthy():
    print("cluster is unhealthy, retrying...")
    time.sleep(1)
print("cluster is healthy")
# Out:
# cluster is healthy

# %%
collections = client.collections.retrieve()
index_name = 'student'
for collection in collections:
    print(collection['name'])
# Out:
# student

# %%
student_schema = {
    'name': index_name,
    'fields': [
        {'name': 'student_id', 'type': 'int64'},
        {'name': 'student_name', 'type': 'string'},
        {'name': 'lastname', 'type': 'string'},
        {'name': 'class_name', 'type': 'string'},
        {
            'name': 'embedding',
            'type': 'float[]',
            'embed': {
                'from': ['lastname'],
                'model_config': {
                    'model_name': 'ts/all-MiniLM-L12-v2',
                },
            },
        },
    ],
    'default_sorting_field': 'student_id',
}

# Create the new collection with the embedding configuration
try:
    client.collections[index_name].delete()
except typesense.exceptions.ObjectNotFound:
    pass
client.collections.create(student_schema)
# Out:
# {'created_at': 1700131020,
#  'default_sorting_field': 'student_id',
#  'enable_nested_fields': False,
#  'fields': [{'facet': False,
#    'index': True,
#    'infix': False,
#    'locale': '',
#    'name': 'student_id',
#    'optional': False,
#    'sort': True,
#    'type': 'int64'},
#   {'facet': False,
#    'index': True,
#    'infix': False,
#    'locale': '',
#    'name': 'student_name',
#    'optional': False,
#    'sort': False,
#    'type': 'string'},
#   {'facet': False,
#    'index': True,
#    'infix': False,
#    'locale': '',
#    'name': 'lastname',
#    'optional': False,
#    'sort': False,
#    'type': 'string'},
#   {'facet': False,
#    'index': True,
#    'infix': False,
#    'locale': '',
#    'name': 'class_name',
#    'optional': False,
#    'sort': False,
#    'type': 'string'},
#   {'embed': {'from': ['lastname'],
#     'model_config': {'model_name': 'ts/all-MiniLM-L12-v2'}},
#    'facet': False,
#    'index': True,
#    'infix': False,
#    'locale': '',
# ...

# %%
document_khdl16a= [
  {
    "student_id": "20011661",
    "student_name": "Trần Hoà Ân",
    "lastname": "Ân"
  },
  {
    "student_id": "20010761",
    "student_name": "Phạm Tấn Lan Anh",
    "lastname": "Anh"
  },
  {
    "student_id": "20028461",
    "student_name": "Đinh Dương Bảo",
    "lastname": "Bảo"
  },
  {
    "student_id": "20083601",
    "student_name": "Nguyễn Quang Bảo",
    "lastname": "Bảo"
  },
  {
    "student_id": "20101811",
    "student_name": "Nguyễn Trần Quốc Bảo",
    "lastname": "Bảo"
  },
  {
    "student_id": "20057571",
    "student_name": "Trần Quốc Bảo",
    "lastname": "Bảo"
  },
  {
    "student_id": "20056951",
    "student_name": "Hồ Xuân Bi",
    "lastname": "Bi"
  },
  {
    "student_id": "20073991",
    "student_name": "Hoàng Đức Chiến",
    "lastname": "Chiến"
  },
  {
    "student_id": "20045061",
    "student_name": "Phạm Anh Chiến",
    "lastname": "Chiến"
  },
  {
    "student_id": "20045391",
    "student_name": "Nguyễn Trường Chinh",
    "lastname": "Chinh"
  },
  {
    "student_id": "20070711",
    "student_name": "Lâm Trường Đảm",
    "lastname": "Đảm"
  },
  {
    "student_id": "20028151",
    "student_name": "Đỗ Nguyên Đạt",
    "lastname": "Đạt"
  },
  {
    "student_id": "20103231",
    "student_name": "Phan Duy Diện",
    "lastname": "Diện"
  },
  {
    "student_id": "20043131",
    "student_name": "Đỗ Thu Đông",
    "lastname": "Đông"
  },
  {
    "student_id": "20000911",
    "student_name": "Võ Khánh Dự",
    "lastname": "Dự"
  },
  {
    "student_id": "20047711",
    "student_name": "Hoàng Thị Ánh Dương",
    "lastname": "Dương"
  },
  {
    "student_id": "20002815",
    "student_name": "Vũ Văn Hà Dương",
    "lastname": "Dương"
  },
  {
    "student_id": "20079601",
    "student_name": "Nguyễn Xuân Giang",
    "lastname": "Giang"
  },
  {
    "student_id": "20001665",
    "student_name": "Nguyễn Văn Hậu",
    "lastname": "Hậu"
  },
  {
    "student_id": "20032501",
    "student_name": "Nguyễn Ngọc Hoan",
    "lastname": "Hoan"
  },
  {
    "student_id": "20002755",
    "student_name": "Phạm Văn Hùng",
    "lastname": "Hùng"
  },
  {
    "student_id": "20029141",
    "student_name": "Trần Văn Hùng",
    "lastname": "Hùng"
  },
  {
    "student_id": "20036941",
    "student_name": "Vũ Văn Hưng",
    "lastname": "Hưng"
  },
  {
    "student_id": "20018991",
    "student_name": "Dương Quang Huy",
    "lastname": "Huy"
  },
  {
    "student_id": "20082051",
    "student_name": "Lê Ngọc Huy",
    "lastname": "Huy"
  },
  {
    "student_id": "20079071",
    "student_name": "Ngô Hoàng Nhật Huy",
    "lastname": "Huy"
  },
  {
    "student_id": "20000831",
    "student_name": "Phạm Duy Huy",
    "lastname": "Huy"
  },
  {
    "student_id": "20107161",
    "student_name": "Phạm Hà Gia Huy",
    "lastname": "Huy"
  },
  {
    "student_id": "20081001",
    "student_name": "Võ Quốc Huy",
    "lastname": "Huy"
  },
  {
    "student_id": "20120721",
    "student_name": "Lưu Gia Khải",
    "lastname": "Khải"
  },
  {
    "student_id": "20036171",
    "student_name": "Trần Quốc Khánh",
    "lastname": "Khánh"
  },
  {
    "student_id": "20030031",
    "student_name": "Mai Anh Khoa",
    "lastname": "Khoa"
  },
  {
    "student_id": "20016701",
    "student_name": "Nguyễn Trần Lâm",
    "lastname": "Lâm"
  },
  {
    "student_id": "20047761",
    "student_name": "Trương Hữu Lợi",
    "lastname": "Lợi"
  },
  {
    "student_id": "20078291",
    "student_name": "Trần Minh Long",
    "lastname": "Long"
  },
  {
    "student_id": "20025031",
    "student_name": "Nguyễn Thanh Nam",
    "lastname": "Nam"
  },
  {
    "student_id": "20020541",
    "student_name": "Quách Xuân Nam",
    "lastname": "Nam"
  },
  {
    "student_id": "20116351",
    "student_name": "Lê Thành Nghĩa",
    "lastname": "Nghĩa"
  },
  {
    "student_id": "20050361",
    "student_name": "Viên Vĩ Nghiệp",
    "lastname": "Nghiệp"
  },
  {
    "student_id": "20123531",
    "student_name": "Nguyễn Chí Nguyện",
    "lastname": "Nguyện"
  },
  {
    "student_id": "20104821",
    "student_name": "Lưu Lương Vi Nhân",
    "lastname": "Nhân"
  },
  {
    "student_id": "20057961",
    "student_name": "Trần Phi Phát",
    "lastname": "Phát"
  },
  {
    "student_id": "20079741",
    "student_name": "Trịnh Hà Gia Phú",
    "lastname": "Phú"
  },
  {
    "student_id": "20072291",
    "student_name": "Phạm Hoàng Phúc",
    "lastname": "Phúc"
  },
  {
    "student_id": "20074861",
    "student_name": "Lê Thanh Quân",
    "lastname": "Quân"
  },
  {
    "student_id": "20002265",
    "student_name": "Lê Văn Quang",
    "lastname": "Quang"
  },
  {
    "student_id": "20053181",
    "student_name": "Bùi Hoàng Sơn",
    "lastname": "Sơn"
  },
  {
    "student_id": "20033951",
    "student_name": "Võ Minh Tâm",
    "lastname": "Tâm"
  },
  {
    "student_id": "20048721",
    "student_name": "Phạm Tiến Thành",
    "lastname": "Thành"
  },
  {
    "student_id": "20101981",
    "student_name": "Thạch Thị Thanh Thảo",
    "lastname": "Thảo"
  },
  {
    "student_id": "20001955",
    "student_name": "Trương Văn Thông",
    "lastname": "Thông"
  },
  {
    "student_id": "20052491",
    "student_name": "Lê Thị Minh Thư",
    "lastname": "Thư"
  },
  {
    "student_id": "20051051",
    "student_name": "Đặng Quốc Toàn",
    "lastname": "Toàn"
  },
  {
    "student_id": "20099181",
    "student_name": "Lê Minh Toàn",
    "lastname": "Toàn"
  },
  {
    "student_id": "20003255",
    "student_name": "Trương Hữu Trí",
    "lastname": "Trí"
  },
  {
    "student_id": "20101671",
    "student_name": "Võ Hoàng Minh Trí",
    "lastname": "Trí"
  },
  {
    "student_id": "20105141",
    "student_name": "Võ Tấn Trọng",
    "lastname": "Trọng"
  },
  {
    "student_id": "20122431",
    "student_name": "Phạm Chánh Trực",
    "lastname": "Trực"
  },
  {
    "student_id": "20098431",
    "student_name": "Võ Quốc Trung",
    "lastname": "Trung"
  },
  {
    "student_id": "20022711",
    "student_name": "Nguyễn Phú Trường",
    "lastname": "Trường"
  },
  {
    "student_id": "20087481",
    "student_name": "Châu Mỹ Uyên",
    "lastname": "Uyên"
  },
  {
    "student_id": "20105361",
    "student_name": "Đặng Chí Viễn",
    "lastname": "Viễn"
  },
  {
    "student_id": "20101511",
    "student_name": "Trương Công Việt",
    "lastname": "Việt"
  }
]
for i in range(len(document_khdl16a)):
    document_khdl16a[i]["class_name"] = "KHDL16A"

# %%
df = pd.DataFrame(document_khdl16a)
df['student_id'] = df['student_id'].astype(int)
document = json.loads(df.to_json(orient='records'))
document
# Out:
# [{'student_id': 20011661,
#   'student_name': 'Trần Hoà Ân',
#   'lastname': 'Ân',
#   'class_name': 'KHDL16A'},
#  {'student_id': 20010761,
#   'student_name': 'Phạm Tấn Lan Anh',
#   'lastname': 'Anh',
#   'class_name': 'KHDL16A'},
#  {'student_id': 20028461,
#   'student_name': 'Đinh Dương Bảo',
#   'lastname': 'Bảo',
#   'class_name': 'KHDL16A'},
#  {'student_id': 20083601,
#   'student_name': 'Nguyễn Quang Bảo',
#   'lastname': 'Bảo',
#   'class_name': 'KHDL16A'},
#  {'student_id': 20101811,
#   'student_name': 'Nguyễn Trần Quốc Bảo',
#   'lastname': 'Bảo',
#   'class_name': 'KHDL16A'},
#  {'student_id': 20057571,
#   'student_name': 'Trần Quốc Bảo',
#   'lastname': 'Bảo',
#   'class_name': 'KHDL16A'},
#  {'student_id': 20056951,
#   'student_name': 'Hồ Xuân Bi',
#   'lastname': 'Bi',
#   'class_name': 'KHDL16A'},
#  {'student_id': 20073991,
#   'student_name': 'Hoàng Đức Chiến',
#   'lastname': 'Chiến',
#   'class_name': 'KHDL16A'},
#  {'student_id': 20045061,
# ...

# %%
client.collections[index_name].documents.import_(document, {'action': 'upsert'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Minh Long\Documents\IUH\Semester 8\CNM\Vis4Teacher_CK\data_processing\typesense.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Minh%20Long/Documents/IUH/Semester%208/CNM/Vis4Teacher_CK/data_processing/typesense.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> client.collections[index_name].documents.import_(document, {'action': 'upsert'})
#
# NameError: name 'client' is not defined

# %%
def search_for_student(teacher_id, query, page=1,per_page=10):
    search_parameters = {
        'q': query,
        'exhaustive_search': 'true',
        'collection': teacher_id,
        'query_by': 'embedding,lastname,student_name',
        'sort_by': '_text_match:desc,_vector_distance:asc',
        'prioritize_exact_match': 'true',
        'prioritize_token_position': 'true',
        'num_typos': '1',
        'vector_query': f'embedding:([], distance_threshold:0.50)',
        'per_page': per_page,
        'page': page
    }

    def extract(result):
        result = result['document']
        result.pop('embedding', None)
        result.pop('id', None)
        return result
    
    results = client.multi_search.perform({
        'searches': [search_parameters]
    }, {})
    # print(results)
    try:
        results = results['results'][0]['hits']
        return list(map(extract, results))
    except:
        return results
        
search_for_student('student', 'Lâ')
# Out:
# [{'class_name': 'KHDL16A',
#   'lastname': 'Lâm',
#   'student_id': 20016701,
#   'student_name': 'Nguyễn Trần Lâm'},
#  {'class_name': 'KHDL16A',
#   'lastname': 'Đảm',
#   'student_id': 20070711,
#   'student_name': 'Lâm Trường Đảm'},
#  {'class_name': 'KHDL16A',
#   'lastname': 'Anh',
#   'student_id': 20010761,
#   'student_name': 'Phạm Tấn Lan Anh'}]

# %%
collections = {
    'test': 
    'test2'
}

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus
host="db.kfcpqkpzqcmneqvpzbrr.supabase.co",
database="postgres",
user="postgres",
port=5432,
password="aiclub@gmail.com"
connection_string = "postgresql://postgres:%s@db.kfcpqkpzqcmneqvpzbrr.supabase.co:5432/postgres" % (quote_plus(password))
engine = create_engine(connection_string)
query = '''
SELECT 
    student_id, student_name, student_gmail, passed_credit, score_10, score_4, score_char, "rank", is_graduated, class_name_id, lastname
FROM public."HomePage_student";
'''

df = pd.read_sql_query(query,con=engine)
df
# Out:
#     student_id         student_name             student_gmail  passed_credit  \
# 0     20011661          Trần Hoà Ân    an.20011661@iuh.edu.vn             45
# 1     20010761     Phạm Tấn Lan Anh   anh.20010761@iuh.edu.vn             35
# 2     20028461      Đinh Dương Bảo   bao.20028461@iuh.edu.vn             37
# 3     20083601     Nguyễn Quang Bảo   bao.20083601@iuh.edu.vn             38
# 4     20057571        Trần Quốc Bảo   bao.20057571@iuh.edu.vn             25
# ..         ...                  ...                       ...            ...
# 198   19446701         Huỳnh Anh Tú    tu.19446701@iuh.edu.vn             59
# 199   19497581  Nguyễn Văn Anh Tuấn  tuan.19497581@iuh.edu.vn             62
# 200   19469421       Phạm Minh Tuấn  tuan.19469421@iuh.edu.vn             51
# 201   19512321   Phan Lê Hoàng Việt  viet.19512321@iuh.edu.vn             52
# 202   19474281         Trần Tuấn Vũ    vu.19474281@iuh.edu.vn             67
#
# ...
